# %%
# %matplotlib inline
# %matplotlib ipympl

import matplotlib.pyplot as plt
import sys
import h5py
import json
import numpy as np
import mplcursors

# %%
from FAmp_duff import FAmp_duff
from plot_floquet_duff import plot_floquet_duff

# %%
FAmp_duff(["FRF1.h5"])
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plot_floquet_duff("FRF1.h5")
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
