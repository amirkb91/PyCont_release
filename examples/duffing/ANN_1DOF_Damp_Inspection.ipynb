# %% [markdown]
# # LNN Performance
#
# This notebook is for:
# - Comparing the analytical vs LNN FRCs

# %%
# Load necessary packages
import jax
import jax.numpy as jnp
import numpy as np
import matplotlib.pyplot as plt

# User-defined
from helpers import compare_sols

from jax import config
config.update("jax_enable_x64", True)

# %% [markdown]
# #### Compare Analytical vs LNN FRCs

# %%
for i in range(1, 11, 1):
    compare_sols(anal_file=f'eq_data/data/FRF{i}', lnn_file=f'eq_data/data_LNN/FRF{i}')
